# %% [markdown]
# <a href="https://colab.research.google.com/github/AlbionKransiqi/Capstone/blob/main/Mask_RCNN_model_(image_size_128x128).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('a')

# %%
for i in range(10,50,10):
  org_image, image_meta, get_class_id, get_box, get_mask =\
      mrcnn.model.load_image_gt(dataset_val, configurations, 
                   z         image_id=i, use_mini_mask=False)
    
    
  visualize.display_instances(org_image, get_box, get_mask, get_class_id, 
                              dataset_val.class_names, figsize=(8, 8))

# %%
print('a')
